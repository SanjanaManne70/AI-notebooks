# %%
#Bag of Words is a special case of Bag of n_grams where n=1
#limitation of bag of n-gram is that as n ^ dimensionality ^ sparsity ^
#Out of Vocabulary problem where during prediction when new words come in..representation becomes difficult so are ignored!!

# %%
#Generating n-gram using CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

v= CountVectorizer()
v.fit(["Thor Hathodawala is looking for a job"])
v.vocabulary_
# Out:
# {'thor': 5, 'hathodawala': 1, 'is': 2, 'looking': 4, 'for': 0, 'job': 3}

# %%
v = CountVectorizer(ngram_range=(1,2))
v.fit(["Thor Hathodawala is looking for a job"])
v.vocabulary_  #note: countvectorizes removes stop words by default
# Out:
# {'thor': 9,
#  'hathodawala': 2,
#  'is': 4,
#  'looking': 7,
#  'for': 0,
#  'job': 6,
#  'thor hathodawala': 10,
#  'hathodawala is': 3,
#  'is looking': 5,
#  'looking for': 8,
#  'for job': 1}

# %%
v = CountVectorizer(ngram_range=(1,3))
v.fit(["Thor Hathodawala is looking for a job"])
v.vocabulary_ #unigram,bigrams,trigrams with indices are returned
# Out:
# {'thor': 12,
#  'hathodawala': 2,
#  'is': 5,
#  'looking': 9,
#  'for': 0,
#  'job': 8,
#  'thor hathodawala': 13,
#  'hathodawala is': 3,
#  'is looking': 6,
#  'looking for': 10,
#  'for job': 1,
#  'thor hathodawala is': 14,
#  'hathodawala is looking': 4,
#  'is looking for': 7,
#  'looking for job': 11}

# %%
corpus = [
    "Thor ate pizza",
    "Loki is tall",
    "Loki is eating pizza"
]

# %%
import spacy

# load english language model and create nlp object from it
nlp = spacy.load("en_core_web_sm") 

def preprocess(text):
    # remove stop words and lemmatize the text
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
    
    return " ".join(filtered_tokens)

# %%
preprocess("Thor ate pizza")
# Out:
# 'thor eat pizza'

# %%
preprocess("Loki is eating pizza")
# Out:
# 'Loki eat pizza'

# %%
corpus_processed = [
    preprocess(text) for text in corpus
]
corpus_processed
# Out:
# ['thor eat pizza', 'Loki tall', 'Loki eat pizza']

# %%
v = CountVectorizer(ngram_range=(1,2))
v.fit(corpus_processed)
v.vocabulary_
# Out:
# {'thor': 7,
#  'eat': 0,
#  'pizza': 5,
#  'thor eat': 8,
#  'eat pizza': 1,
#  'loki': 2,
#  'tall': 6,
#  'loki tall': 4,
#  'loki eat': 3}

# %%
v.transform(["Thor eat pizza"]).toarray()
# Out:
# array([[1, 1, 0, 0, 0, 1, 0, 1, 1]], dtype=int64)

# %%
v.transform(["Hulk eat pizza"]).toarray()
#"Hulk" is ignored bcoz it wasn't in the fitted vocabulary
#OOV (Out Of Vocabulary)
# Out:
# array([[1, 1, 0, 0, 0, 1, 0, 0, 0]], dtype=int64)
