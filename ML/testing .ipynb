# %%
#changing training dataset!!!!!
import pandas as pd
df= pd.read_csv("testing.csv")
df.head()
# Out:
#    mileage  age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          35100

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['mileage'],df['Sell Price($)'])

# %%
x=df[['mileage','age(yrs)']]
y= df['Sell Price($)']

# %%
x
# Out:
#     mileage  age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     35100
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 12

# %%
len(x_test)
# Out:
# 3

# %%
x_train
# Out:
#     mileage  age(yrs)
# 5     59000         5
# 8     91000         8
# 14    82450         7
# 6     52000         5
# 10    83000         7
# 9     67000         6
# 3     22500         2
# 12    59000         5
# 11    79000         7
# 0     69000         6
# 7     72000         6
# 13    58780         4

# %%
from sklearn.linear_model import LinearRegression
clf= LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([31401.93144894, 27041.32326634, 35762.53963154])

# %%
y_test
# Out:
# 4    35100
# 2    26100
# 1    34000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.6334874888774462
